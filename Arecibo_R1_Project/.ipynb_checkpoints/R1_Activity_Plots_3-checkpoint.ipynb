# %% [markdown]
# # Notes

# %% [markdown]
# This notebook contains code for R1 activity phase plotting.
#
# It contains a copy of code from: R1_Activity_Plots_2.ipynb which has been modified to allow plots of multiple frequency ranges simultaneously.
#
# It uses data stored in JSON format and created using: R1_Load_Data.ipynb
#
# It was created for laura for an effelsberg observing proposal.

# %% [markdown]
# # Imports

# %%
import json
import numpy as np
from astropy.timeseries import TimeSeries as ts
from matplotlib import pyplot as plt
from astropy.time import Time
from astropy import units as u
from scipy.signal import lombscargle as ls
import astropy
from astropy.modeling import models, fitting

# %% [markdown]
# # Functions

# %%
#Kenzie Nimmo's ChiSq code:

def chisq(N,exp):
    """
    N = binned number of bursts
    exp = exposure time per bin
    """
    p=float(np.sum(N)/np.sum(exp))

    E = np.zeros_like(N)
    for binno in range(len(N)):
        E[binno] = p*exp[binno]
    
    chisq_stat=np.sum((N-E)**2/(E))
    
    return chisq_stat


def folding(beginp,endp,bins,burst_times,begin_times,end_times):
    """
    beginp and endp are the beginning and end trial periods to fold in days
    bins is an integer number of bins to divide your period into
    burst_times is an array of the observation days which contains a burst
    begin_times is an array of the observation begin times with AND without bursts
    end_times is an array of the observation end times with AND without bursts
    """
    freqs=np.arange(1./float(endp),1./float(beginp),(1./float(bins))/(np.max(burst_times)-np.min(burst_times)))
    #print(freqs)
    periods = np.sort(1./freqs) #days
    #print(periods)
    
    #fig=plt.figure(figsize=(4,3))
    #ax=fig.add_subplot(111)
    #ax.plot(periods,marker='o',label='periods')
    #ax.plot(freqs,marker='o',label='frequencies')
    #ax.legend()
    #plt.show()
    
    t0=begin_times.min()
    tend=end_times.max()

    chisq_values=[]
    ps=[]
    #for pind,p in enumerate(tqdm(periods)): #removed tqdm for now
    for pind,p in enumerate(periods):
        bin_length= p/float(bins) #days
        binned=np.zeros(bins)
        exposure=np.zeros(bins)
        for i in range(int(np.ceil((tend-t0)/bin_length))): #chop up into bins
            if i==0:
                begin_time = t0 + i*bin_length
            else: begin_time = end_time
            end_time = begin_time + bin_length
            above=np.where(burst_times >= begin_time) 
            below=np.where(burst_times < end_time )
            count=len(np.intersect1d(above,below)) #find the bursts within the begin_time and end_time of the bin
            binned[(i)%bins]+=count #adding a count each time a burst falls in a particular bin
            # compute the exposure
            time_before=np.where(begin_times < end_time)
            time_after=np.where(end_times > begin_time)
            overlap_with_bin=np.intersect1d(time_before,time_after)
            for over in range(len(overlap_with_bin)):
                if begin_times[overlap_with_bin[over]] <= begin_time:
                    begin_exp = begin_time
                else: begin_exp = begin_times[overlap_with_bin[over]]
                if end_times[overlap_with_bin[over]] >= end_time:
                    end_exp = end_time
                else: end_exp = end_times[overlap_with_bin[over]]
            exp = ((end_exp-begin_exp)*24.*3600.) 
            exposure[(i)%bins]+=exp #adding exposure per bin in seconds 
        #print(chisq(binned,exposure))
        chisqp=float(chisq(binned,exposure))/(bins-1)
        chisq_values.append(chisqp)
        ps.append(p)
    return chisq_values, ps

def TallyBursts(ObservingTimes,ObservingDurations,BurstMJDs):
    """
    For papers which provide burst data but not observing information, we must find the observing 
    files where these bursts were stored on dop263.
    
    The bursts must then be tallied into their respective observations. This function does this.
    
    INPUTS:
    
    ObservingTimes     : [array of astropy mjd values] List of observation start times which
                         contained bursts. Must be calculated from observing data.
    ObservingDurations : [array of astropy seconds values] List of observation durations in u.s.
                         Must be calculated from observing data.
    BurstMJDs          : [array of floats] List of mjd values of the bursts observed. Must NOT
                         be an astropy time quantity.
    
    
    RETURNS:
    
    TalliedEvents : [array of ints of shape equal to list of observing times]
    """
    
    
    TalliedEvents = np.zeros_like(ObservingTimes)

    #print(TalliedEvents)
    for i in range(len(BurstMJDs)): #loop over marcote bursts
        for j in range(len(ObservingTimes)): #loop over observation start times
            if (Time(BurstMJDs[i],format='mjd') > ObservingTimes[j]) & (Time(BurstMJDs[i],format='mjd') < ObservingTimes[j] + ObservingDurations[j]): #if burst falls into obs
                #print(True)
                TalliedEvents[j]+=1 #tally burst
    if np.sum(TalliedEvents) != len(BurstMJDs):
        print('warning! Not all bursts are tallied. Code is wrong.')
    else:
        print('bursts tallied.')
        
    return TalliedEvents

# %% [markdown]
# # Load data from JSON files

# %%
########################
#load L and C-band data#
########################

jsonfile = 'AnyBand_R1.json' #the file containing the data
#jsonfile = 'LBand_R1.json' #the file containing the data


with open(jsonfile, 'r') as f: #open file
    r1_data = json.load(f) #load all data

#print keys (i.e. data) for reference
print('Data Keys: {0}\n'.format(r1_data.keys())) 


###################################################
#extract keys I will use to filter or process data#
###################################################

burst_dict = r1_data['bursts'] #mjds of bursts
tel_dict = r1_data['obs_tels'] #telescopes of observtions
freq_dict = r1_data['obs_freqs'] #frequencies of observations
dura_dict = r1_data['obs_duration'] #duration of all observations
start_dict = r1_data['obs_startmjds'] #strt mjds of all observations
bpo_dict = r1_data['bursts_per_obs'] #detected events in each observation

#print keys (i.e. particular observing setups) for reference
print('Setup keys: {0}\n'.format(burst_dict.keys()))
# Out:
# Data Keys: dict_keys(['bursts', 'obs_duration', 'obs_startmjds', 'bursts_per_obs', 'obs_tels', 'obs_freqs', 'references'])
#
# Setup keys: dict_keys(['Cruces21a', 'Hardy17a', 'Houben19a', 'ALFA16a', 'Scholtz16a', 'Hewitt22a', 'Scholtz17a', 'Jahns22a', 'Marcote16a', 'MAGIC17a', 'Rajwade20a', 'Oostrum17a', 'CalebMeerKAT20a', 'CalebSardinia20a', 'CalebNancay20a', 'Michilli18a', 'Spitler18a', 'Zhang18a'])

# %% [markdown]
# # Function to extract bursts to be plotted

# %%
def WeightedPhasePlot(data_file='AnyBand_R1.json',
                      tels=['Nancay','Effelsberg','Nancay','Sardinia','Arecibo','Lovell','GBT','WSRT','MeerKAT'],
                      min_freq=[1,2],
                      max_freq=[2,10],
                      fold_period=161,
                      verbose=False):
    """
    Function which extracts FRB121102 bursts from a data dictionary and creates weighted phase plots.
    Creates plots for lists of frequency ranges.
    If you only wish to plot for one frequency range, make min_freq and max_freq lists one element long.
    
    INPUTS
    
    data_file   : [str] name of .json data file containing observations to be used. 
                        (must be created with R1_Load_Data.ipynb)
    tels        : [list of str] list of telescopes in the data dictionary to use observations from.
    min_freq    : [list of floats] the minimum frequency of the observing band to
                                   plot weighted phase plot for (in GHz)
    max_freq    : [list of floats] the maximum frequency of the observing band to
                                   plot weighted phase plot for (in GHz)
    fold_period : [float] activity period to fold bursts over in days.
                          Default = 161 days (derived from Cruces+21)
    verbose     : [binary] if true, prints statements for checking
    
    RETURNS
    
    
    
    """
    
    ##############
    #Check inputs#
    ##############
    
    if type(min_freq) is not list:
        print('Error 1, min and max freqs must be lists of equal length')
        return None
        
    if type(max_freq) is not list:
        print('Error 2, min and max freqs must be lists of equal length')
        return None
    
    if len(min_freq)!=len(max_freq):
        print('Error 3, min and max freqs must be lists of equal length')
        return None    
    
    #######################
    #load observation data#
    #######################

    jsonfile = data_file #the file containing the data

    with open(jsonfile, 'r') as f: #open file
        r1_data = json.load(f) #load all data

    #print keys (i.e. data) for reference
    if verbose==True:
        print('Data Keys: {0}\n'.format(r1_data.keys())) 
    
    #get activity period to fold over in days
    Cruces_p = fold_period #[days]
    
    ##########################################################
    #get t0 (i.e. initial time of very first burst ). We will#
    #use this t0 when folding for every freq range we process#
    #to ensure we can compare the different freq range phases#
    ##########################################################
    
    min_array = [] #initialise array to hold first burst time from each dataset
    for key in r1_data['bursts'].keys(): #loop over ALL datasets
        try: #for each dataset...
            min_array.append(Time(np.min(r1_data['bursts'][key]),format='mjd')) #get first burst time
        except: #catch error if the observation contained no bursts
            print('Did not use {0} bursts when deciding folding t0 (maybe because it has no bursts, check this manually)'.format(key))
    data_t0 = Time(np.min(min_array),format='mjd') #get first burst time considering ALL datasets

    ###################################################
    #extract keys I will use to filter or process data#
    ###################################################

    burst_dict = r1_data['bursts'] #mjds of bursts
    tel_dict = r1_data['obs_tels'] #telescopes of observtions
    freq_dict = r1_data['obs_freqs'] #frequencies of observations
    dura_dict = r1_data['obs_duration'] #duration of all observations
    start_dict = r1_data['obs_startmjds'] #strt mjds of all observations
    bpo_dict = r1_data['bursts_per_obs'] #detected events in each observation
    print('All references: ',r1_data['references'])

    #print keys (i.e. particular observing setups) for reference
    if verbose==True:
        print('Setup keys: {0}\n'.format(burst_dict.keys())) 
    
    #################
    #initialise plot#
    #################
    
    fig = plt.figure(figsize=(12,12))
    ax1=fig.add_subplot(311)
    ax1.set_title('Telescopes: {0}\nBursts folded manually over period of: {1} days'.format(tels,Cruces_p),fontsize=15)
    ax1.set_xlabel('Phase',fontsize=20)
    ax1.set_ylabel('Burst Count',fontsize=20)
    ax1.tick_params(axis='x',labelsize=20)
    ax1.tick_params(axis='y',labelsize=20)
    
    ax2=fig.add_subplot(312)
    ax2.set_title('Observation durations (manual fold over period: {0} days)'.format(Cruces_p),fontsize=15)
    ax2.set_xlabel('Phase',fontsize=20)
    ax2.set_ylabel('Observing length [hours]',fontsize=20)
    ax2.tick_params(axis='x',labelsize=20)
    ax2.tick_params(axis='y',labelsize=20)
    
    ax3=fig.add_subplot(313)
    ax3.set_title('Weighted count (manual fold over period: {0} days)'.format(Cruces_p),fontsize=15)
    ax3.set_xlabel('Phase',fontsize=20)
    ax3.set_ylabel('Count/hours',fontsize=20)
    ax3.tick_params(axis='x',labelsize=20)
    ax3.tick_params(axis='y',labelsize=20)

    #########################################
    #loop over frequency ranges, do plotting#
    #########################################
    
    for i in range(len(min_freq)): #choose frequency range to plot
    
        ##################################################################
        #construct a data filter (e.g. select only L-band Arecibo bursts)#
        ##################################################################

        #choose filter inputs
        minfreq_filter = min_freq[i] #[GHz] #inlude bursts detected in bands above this min freq
        maxfreq_filter = max_freq[i] #[GHz] #include bursts detected in bands below this max freq
        telescope_filter = tels#['Nancay','Effelsberg','Nancay','Sardinia','Arecibo','Lovell','GBT','WSRT','MeerKAT'] #telescopes of choice to include data from

        #####################################################################################
        #loop over all burst data and extract only data from setups which comply with filter#
        #####################################################################################

        #initialise arrays to hold bursts (and corresponding data) to use
        bursts_to_use = [] #mjds of bursts
        bpos_to_use = [] #events per observation
        duras_to_use = [] #observation durations [s]
        starts_to_use = [] #observation start mjds

        #pick out bursts to use from all bursts
        for k in burst_dict.keys(): #loop over data

            if verbose==True:
                print('Telescope: {0}'.format(tel_dict[k]))
                print('Frequency: {0} GHz'.format(freq_dict[k]))

            #construct data filter from filter inputs
            data_filter = ((freq_dict[k]>minfreq_filter)&(freq_dict[k]<maxfreq_filter))&(np.isin(tel_dict[k],telescope_filter))
            if verbose==True:
                print('Filter passed: {0}'.format(data_filter))

            #select only data which passes filter
            if data_filter==True:

                #store selected data to their arrays
                if verbose==True:
                    print(burst_dict[k])
                bursts_to_use += burst_dict[k]  #burst mjds
                bpos_to_use += bpo_dict[k] #events per observation
                duras_to_use += dura_dict[k] #observation durations [s]
                starts_to_use += start_dict[k] #start mjds of observations
                #burstfreqs_to_use += freq_dict[k]
                #print(freq_dict[k])
                print('References used for band {0}:'.format(i),r1_data['references'][k])


        if verbose==True:
            print('bursts to use: {0}'.format(bursts_to_use))

        #####################
        #Do the calculations#
        #####################

        #get the phase data manually

        #choose bins
        bins = np.linspace(0,1,40)

        #initial time of first observation
        #data_t0 = Time(np.min(bursts_to_use),format='mjd')
                
        #print(data_t0)

        #arrival times after first observation 
        data_burst_tarr = (Time(bursts_to_use,format='mjd')-data_t0).value
        #print(data_burst_tarr)

        #times of observations after first observation
        data_obs_tarr = (Time(starts_to_use,format='mjd')-data_t0).value
        #print(data_obs_tarr)

        #burst arrival times as a function of phase according to Cruces+21 period
        burst_phase = (data_burst_tarr/Cruces_p)-(data_burst_tarr//Cruces_p) 

        #observing times as a function of phase according to Cruces+21 period
        obs_phase = (data_obs_tarr/Cruces_p)-(data_obs_tarr//Cruces_p)

        #observing lengths corresponding to these times/phases
        obs_len = (duras_to_use*u.s).to(u.hr).value #convert from seconds to hours


        #################
        #do the plotting#
        #################

        ax1.set_yscale('log')
        burstphase=ax1.hist(burst_phase,bins=bins,label='Band: {0:.2f}-{1:.2f} GHz'.format(minfreq_filter,maxfreq_filter))

        ax1.legend(fontsize=20)



        #sum observing lengths according to bins of observing phase
        #method from: 
        # https://stackoverflow.com/questions/51392433/sum-one-numpy-array-based-on-bins-of-another)
        # https://numpy.org/doc/stable/reference/generated/numpy.histogram.html
        #i.e.: each value in obs_phase contributes its associated length towards the bin count (instead of 1)

        ax2.set_yscale('log')

        obsphase = ax2.hist(obs_phase,bins=bins,weights=obs_len,label='Band: {0:.2f}-{1:.2f} GHz'.format(minfreq_filter,maxfreq_filter))

        ax2.legend(fontsize=20)

        #instructions to get np.histogram to plot like plt.hist here:
        # https://stackoverflow.com/questions/46656010/plt-hist-vs-np-histogram-unexpected-results

        burstphase_cnts, burstphase_bins = np.histogram(burst_phase,bins=bins)
        obsphase_cnts, obsphase_bins = np.histogram(obs_phase,bins=bins,weights=obs_len)

        
        ax3.set_yscale('log')
        ax3.bar(obsphase_bins[:-1] + np.diff(obsphase_bins) / 2, burstphase_cnts/obsphase_cnts, np.diff(bins),label='Band: {0:.2f}-{1:.2f} GHz'.format(minfreq_filter,maxfreq_filter))

        ax3.legend(fontsize=20)
        
    plt.tight_layout()
    plt.savefig('Observing_proposal.pdf',format='pdf')
    plt.show()
    
    return

# %%
data_file='AnyBand_R1.json'
tels=['Nancay','Effelsberg','Nancay','Sardinia','Arecibo','Lovell','GBT','WSRT','MeerKAT']
min_freq=[1,4]
max_freq=[2,8]
fold_period=161




WeightedPhasePlot(data_file,tels,min_freq,max_freq,fold_period,verbose=False)
# Out:
# Did not use Scholtz16a bursts when deciding folding t0 (maybe because it has no bursts, check this manually)
# Did not use CalebSardinia20a bursts when deciding folding t0 (maybe because it has no bursts, check this manually)
# Did not use CalebEffelsberg20a bursts when deciding folding t0 (maybe because it has no bursts, check this manually)
# All references:  {'Cruces21a': ['https://ui.adsabs.harvard.edu/abs/2021MNRAS.500..448C/abstract'], 'Hardy17a': ['https://ui.adsabs.harvard.edu/abs/2017MNRAS.472.2800H/abstract'], 'Houben19a': ['https://ui.adsabs.harvard.edu/abs/2019A%26A...623A..42H/abstract'], 'ALFA16a': ['https://ui.adsabs.harvard.edu/abs/2016Natur.531..202S/abstract', 'https://ui.adsabs.harvard.edu/abs/2016ApJ...833..177S/abstract'], 'Scholtz16a': ['https://ui.adsabs.harvard.edu/abs/2016ApJ...833..177S/abstract', 'https://ui.adsabs.harvard.edu/abs/2021arXiv211111282H/abstract'], 'Hewitt22a': ['https://ui.adsabs.harvard.edu/abs/2021arXiv211111282H/abstract'], 'Scholtz17a': ['https://ui.adsabs.harvard.edu/abs/2017ApJ...846...80S/abstract'], 'Jahns22a': ['https://ui.adsabs.harvard.edu/abs/2022arXiv220205705J/abstract'], 'Marcote16a': ['https://ui.adsabs.harvard.edu/abs/2017ApJ...834L...8M/abstract', 'dop263:/data/FRB121102/pipeline_products/puppi_57651_C0531+33_0004'], 'MAGIC17a': ['https://ui.adsabs.harvard.edu/abs/2018MNRAS.481.2479M/abstract', 'dop263:/data/FRB121102/pipeline_products/puppi_57806_C0531+33_0144', 'dop263:/data/FRB121102/pipeline_products/puppi_57807_frb_0165', 'dop263:/data/FRB121102/pipeline_products/puppi_57807_frb_0165'], 'Rajwade20a': ['https://ui.adsabs.harvard.edu/abs/2020MNRAS.495.3551R/abstract'], 'Oostrum17a': ['https://www.astronomerstelegram.org/?read=10693'], 'CalebMeerKAT20a': 'https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract', 'CalebSardinia20a': 'https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract', 'CalebNancay20a': 'https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract', 'Michilli18a': ['https://ui.adsabs.harvard.edu/abs/2018Natur.553..182M/abstract'], 'Spitler18a': ['https://ui.adsabs.harvard.edu/abs/2018ApJ...863..150S/abstract'], 'Zhang18a': ['https://ui.adsabs.harvard.edu/abs/2018ApJ...866..149Z/abstract'], 'CalebEffelsberg20a': 'https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract'}
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2021MNRAS.500..448C/abstract']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2017MNRAS.472.2800H/abstract']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2019A%26A...623A..42H/abstract']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2016Natur.531..202S/abstract', 'https://ui.adsabs.harvard.edu/abs/2016ApJ...833..177S/abstract']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2016ApJ...833..177S/abstract', 'https://ui.adsabs.harvard.edu/abs/2021arXiv211111282H/abstract']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2021arXiv211111282H/abstract']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2017ApJ...846...80S/abstract']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2022arXiv220205705J/abstract']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2017ApJ...834L...8M/abstract', 'dop263:/data/FRB121102/pipeline_products/puppi_57651_C0531+33_0004']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2018MNRAS.481.2479M/abstract', 'dop263:/data/FRB121102/pipeline_products/puppi_57806_C0531+33_0144', 'dop263:/data/FRB121102/pipeline_products/puppi_57807_frb_0165', 'dop263:/data/FRB121102/pipeline_products/puppi_57807_frb_0165']
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2020MNRAS.495.3551R/abstract']
# References used for band 0: ['https://www.astronomerstelegram.org/?read=10693']
# References used for band 0: https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract
# References used for band 0: https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract
# References used for band 1: ['https://ui.adsabs.harvard.edu/abs/2018Natur.553..182M/abstract']
# References used for band 1: ['https://ui.adsabs.harvard.edu/abs/2018ApJ...863..150S/abstract']
# References used for band 1: ['https://ui.adsabs.harvard.edu/abs/2018ApJ...866..149Z/abstract']
# References used for band 1: https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract
# /tmp/ipykernel_103190/813531455.py:236: RuntimeWarning: invalid value encountered in true_divide
#   ax3.bar(obsphase_bins[:-1] + np.diff(obsphase_bins) / 2, burstphase_cnts/obsphase_cnts, np.diff(bins),label='Band: {0:.2f}-{1:.2f} GHz'.format(minfreq_filter,maxfreq_filter))

# %%
data_file='AnyBand_R1.json'
#tels=['Nancay','Effelsberg','Nancay','Sardinia','Arecibo','Lovell','GBT','WSRT','MeerKAT']
tels=['Effelsberg']
min_freq=[4]
max_freq=[8]
fold_period=161




WeightedPhasePlot(data_file,tels,min_freq,max_freq,fold_period,verbose=False)
# Out:
# Did not use Scholtz16a bursts when deciding folding t0 (maybe because it has no bursts, check this manually)
# Did not use CalebSardinia20a bursts when deciding folding t0 (maybe because it has no bursts, check this manually)
# Did not use CalebEffelsberg20a bursts when deciding folding t0 (maybe because it has no bursts, check this manually)
# All references:  {'Cruces21a': ['https://ui.adsabs.harvard.edu/abs/2021MNRAS.500..448C/abstract'], 'Hardy17a': ['https://ui.adsabs.harvard.edu/abs/2017MNRAS.472.2800H/abstract'], 'Houben19a': ['https://ui.adsabs.harvard.edu/abs/2019A%26A...623A..42H/abstract'], 'ALFA16a': ['https://ui.adsabs.harvard.edu/abs/2016Natur.531..202S/abstract', 'https://ui.adsabs.harvard.edu/abs/2016ApJ...833..177S/abstract'], 'Scholtz16a': ['https://ui.adsabs.harvard.edu/abs/2016ApJ...833..177S/abstract', 'https://ui.adsabs.harvard.edu/abs/2021arXiv211111282H/abstract'], 'Hewitt22a': ['https://ui.adsabs.harvard.edu/abs/2021arXiv211111282H/abstract'], 'Scholtz17a': ['https://ui.adsabs.harvard.edu/abs/2017ApJ...846...80S/abstract'], 'Jahns22a': ['https://ui.adsabs.harvard.edu/abs/2022arXiv220205705J/abstract'], 'Marcote16a': ['https://ui.adsabs.harvard.edu/abs/2017ApJ...834L...8M/abstract', 'dop263:/data/FRB121102/pipeline_products/puppi_57651_C0531+33_0004'], 'MAGIC17a': ['https://ui.adsabs.harvard.edu/abs/2018MNRAS.481.2479M/abstract', 'dop263:/data/FRB121102/pipeline_products/puppi_57806_C0531+33_0144', 'dop263:/data/FRB121102/pipeline_products/puppi_57807_frb_0165', 'dop263:/data/FRB121102/pipeline_products/puppi_57807_frb_0165'], 'Rajwade20a': ['https://ui.adsabs.harvard.edu/abs/2020MNRAS.495.3551R/abstract'], 'Oostrum17a': ['https://www.astronomerstelegram.org/?read=10693'], 'CalebMeerKAT20a': 'https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract', 'CalebSardinia20a': 'https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract', 'CalebNancay20a': 'https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract', 'Michilli18a': ['https://ui.adsabs.harvard.edu/abs/2018Natur.553..182M/abstract'], 'Spitler18a': ['https://ui.adsabs.harvard.edu/abs/2018ApJ...863..150S/abstract'], 'Zhang18a': ['https://ui.adsabs.harvard.edu/abs/2018ApJ...866..149Z/abstract'], 'CalebEffelsberg20a': 'https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract'}
# References used for band 0: ['https://ui.adsabs.harvard.edu/abs/2018ApJ...863..150S/abstract']
# References used for band 0: https://ui.adsabs.harvard.edu/abs/2020MNRAS.496.4565C/abstract
# /tmp/ipykernel_103190/813531455.py:236: RuntimeWarning: invalid value encountered in true_divide
#   ax3.bar(obsphase_bins[:-1] + np.diff(obsphase_bins) / 2, burstphase_cnts/obsphase_cnts, np.diff(bins),label='Band: {0:.2f}-{1:.2f} GHz'.format(minfreq_filter,maxfreq_filter))
